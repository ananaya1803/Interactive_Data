# %% [markdown]
# # Ananaya Bhatnagar
# ## MS EMAT
# **Tech up skills**
# *Learning a new language*
# *Interested in becoming a Project Manager and would like to understand data better*
#
# ![Image](https://miro.medium.com/max/1200/1*Z8c1soDFmQuE5LjmmlWIrg.png)

# %%
my_semester = "3"
my_semester
# Out:
# '3'

# %%
def print_name ():
    print("Ananaya")

print_name ()
# Out:
# Ananaya

# %%
def semester():
    return my_semester

# %%
spring_semester = semester()
spring_semester
# Out:
# '3'
